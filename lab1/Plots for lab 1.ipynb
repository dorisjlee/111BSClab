# %%
% pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1.1.20

# %% [markdown]
# ### Oscilloscope

# %%
f1 = [10.,31.6,100.,316.,1000.,3160.,10000.,31600,1e5,2e5,316000,3e5,1e6,3e6,5e6,6e6,7e6,5.5e6,7.5e6,8e6,8.5e6,9e6,9.5e6,1e7]
v1 = [480e-3,480e-3,480e-3,480e-3,480e-3,480e-3,480e-3,485e-3,485e-3,485e-3,490e-3,490e-3,490e-3,490e-3,495e-3,1.02,1.03,1.015,1.04,1.06,1.06,1.08,1.09,1.10]

# %%
plt.title("Oscilloscope",fontsize=12)
plt.xlabel("Frequency (Hz)",fontsize=12)
plt.ylabel("$V_0$(V)",fontsize=12)
plt.plot(f1,v1,'o')
plt.plot(f1,v1,'r-')

# %% [markdown]
# ##### On loglog scale

# %%
plt.title("Oscilloscope",fontsize=12)
plt.xlabel("log Frequency (Hz)",fontsize=12)
plt.ylabel("log $V_0$(V)",fontsize=12)
plt.loglog(f1,v1,'o')
plt.loglog(f1,v1,'r-')

# %% [markdown]
# ### DMM

# %%
f2  =  [10.,31.6,100.,316.,1000.,3160.,10000.,31600,1e5,316000,1e6,2e6,2.25e6,2.5e6,3e6,3.1e6]
v2 =  [0.35388,0.35382,0.35356,0.35329,0.35319,0.35319,0.35331,0.35342,0.35360,0.36220,0.51622,56.538e-3,32.921e-3,18.033e-3,3.925e-3,1.634e-3]

# %%
plt.title("Oscilloscope",fontsize=12)
plt.xlabel("Frequency (Hz)",fontsize=12)
plt.ylabel("$V_0$(V)",fontsize=12)
plt.plot(f2,v2,'o')
plt.plot(f2,v2,'r-')

# %%
plt.title("Oscilloscope",fontsize=12)
plt.xlabel("log Frequency (Hz)",fontsize=12)
plt.ylabel("log $V_0$(V)",fontsize=12)
plt.loglog(f2,v2,'o')
plt.loglog(f2,v2,'r-')

# %% [markdown]
# # 1.2.1 Thevinin analysis

# %%
r = [1000,10000,100]#[ohm]
v = [4.129,4.1251,4.1286]#[V]
i = [0.9626,0.3160,1.2495]#[mA]

# %%
# plt.title("Oscilloscope",fontsize=12)
plt.xlabel("Voltage (V)",fontsize=12)
plt.ylabel("Current (mA)",fontsize=12)
plt.plot(v,i,'o')
plt.plot(v,i,'r-')

# %%
r = [100,1000,10000] #[ohm]
v = [0.1440,1.131,3.585] #
i = np.array([1.448e-3,1.138e-3,0.3625e-3])*1000 #[A]

# %%
fit_and_plot(v,i, xlabel="Voltage (V)",ylabel="Current (A)", title= "Thevenin Circuit", right_words=True)
# Out:
# [-0.31556651  1.49405108]
#
# -0.3156 x + 1.494
# poly1d([-0.31556651,  1.49405108])

# %%
r_1 = 1./(1./3.1367e3+1./1e3)
r_1
# Out:
# 758.2614161046243

# %%
vt = 7.28+8.49

# %%
vt/(r_1)
# Out:
# 0.020797576752638127

# %%
def fit_and_plot(x,y,xlabel="",ylabel="",title="",zeroed=False,annotate_fit= True,right_words = False,error_bar=""):
#     x=1./x**2
#     y=1./y
#     fig = plt.figure()
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.plot(x,y,'o')
    z = np.polyfit(x,y, 1) 
    print z
    p = np.poly1d(z)
    print p
    if zeroed : 
        a = np.linspace(0,max(x))
    else:
        a = np.linspace(min(x),max(x))
    ax1.plot(a, p(np.linspace(min(x),max(x))),color="red")
    if annotate_fit: 
        slope = z[0]
        intercept = z[1]
        if right_words:    
            ax1.text(0.48,0.85,"y= %.5f x + %.5f"%(slope,intercept), fontsize=13,transform=ax1.transAxes)
        else:
            ax1.text(0.03,0.85,"y= %.5f x + %.5f"%(slope,intercept), fontsize=13,transform=ax1.transAxes)
    if title !="":
        plt.title(title,fontsize=13 )    
        plt.xlabel(xlabel,fontsize=12)
        plt.ylabel(ylabel,fontsize=12)
#     ax1 = fig.add_subplot(111)
#     ax1.text(0.03,0.8,"y= %.5f x %.5f"%(p[0],p[1]), fontsize=13,transform=ax.transAxes)
    if error_bar!="":
        ax1.errorbar(x, y, yerr=error_bar, fmt='o')
    plt.tick_params(axis='both', which='major', labelsize=12)
    plt.tick_params(axis='both', which='minor', labelsize=12)
    return p

# %% [markdown]
# # 1.2.3

# %%
# r = np.array([0,200,470,820,1000,2200])# [kohm]
r = np.array([0,200e3,470e3,820e3,1e6,2.2e6])# [ohm]
v = np.array([0.719,0.590,0.686,0.664,0.651,584.8e-3]) #[V]
# plt.plot(r,v,'o')
p1 = fit_and_plot(r,v,"Resistance[ohm]]", "Voltage[V]","V-I plot for finding Z input"  )
# Out:
# [ -3.92546544e-08   6.79817388e-01]
#
# -3.925e-08 x + 0.6798

# %% [markdown]
# ### Bad fit remove outlier

# %%
r = [0,200, 820,1000,2200]# [kohm]
v = [0.719, 0.686,0.664,0.651,584.8e-3] #[V]
# plt.plot(r,v,'o')
p1 = fit_and_plot(r,v,"Current[A]", "Voltage[V]","V-I plot for finding Z input"  )
# Out:
# [ -5.68462444e-05   7.08938230e-01]
#
# -5.685e-05 x + 0.7089

# %%
import mpld3

# %%
mpld3.disable_notebook()

# %%
# r = np.array([470,820,1000,2200])# [kohm]
r = np.array([470e3,820e3,1e6,2.2e6])# [ohm]
v_in = np.array([0.686,0.664,0.651,584.8e-3]) #[V]
v_ext =1.
I_in = I_in[np.where(r>0)]
I_in = (v_ext - v_in)/(r) #[A]
# I_in = list(I_in)
# I_in.append(0)
# I_in = np.array(I_in)
# print I_in
# plt.plot(I_in,v_in[np.where(r>0)],'o')
# v_in =list(v_in)
# v_in.append(0)
# v_in = np.array(v_in)
# print v_in
yerr = np.append(compute_uncertainty(v_in[:-1],0.001),compute_uncertainty(v_in[-1],0.1e-3))
print yerr#.flatten(1)
p1 = fit_and_plot(I_in,v_in,"Current[A]", "Voltage[V]","V-I plot for finding Z input",zeroed=True,error_bar=yerr)
# Out:
# [  8.23600000e-05   7.97200000e-05   7.81600000e-05   7.01800000e-05]
# [  1.97806168e+05   5.66557648e-01]
#
# 1.978e+05 x + 0.5666

# %%
v_in
# Out:
# array([ 0.686 ,  0.664 ,  0.651 ,  0.5848])

# %%
I_in
# Out:
# array([  6.67658941e-05,   4.09606242e-05,   3.48895331e-05,
#          1.88701541e-05])

# %% [markdown]
# # 1.2.4

# %%
r = np.array([2.2e6,470e3,820e3,1e6,2.2e6])# [ohm]
v_in = np.array([0.20848,0.47139,0.37797,0.71532,0.33504])#[V]
v_ext =1.
I_in = I_in[np.where(r>0)]
I_in = (v_ext - v_in)/(r) #[A]
# I_in = list(I_in)
# I_in.append(0)
# I_in = np.array(I_in)
# print I_in
# plt.plot(I_in,v_in[np.where(r>0)],'o')
# v_in =list(v_in)
# v_in.append(0)
# v_in = np.array(v_in)
# print v_in
yerr = np.append(compute_uncertainty(v_in[:-1],0.001),compute_uncertainty(v_in[-1],0.1e-3))
print yerr#.flatten(1)
p1 = fit_and_plot(I_in,v_in,"Current[A]", "Voltage[V]","V-I plot for finding Z input",zeroed=True,error_bar=yerr)
# Out:
# [  2.50576000e-05   5.66068000e-05   4.53964000e-05   8.58784000e-05
#    4.02088000e-05]
# [  6.59719504e+03   4.17905999e-01]
#
# 6597 x + 0.4179

# %%
r = np.array([2.2e6,470e3,820e3,1e6,2.2e6])# [ohm]
v = np.array([0.20848,0.47139,0.37797,0.71532,0.33504])#[V]
v_ext =1
# I_in = I_in[np.where(r>0)]
I_in = (v_ext - v)/(r) #[A]
print I_in
# yerr = np.append(compute_uncertainty(v_in[:-1],0.001),compute_uncertainty(v_in[-1],0.1e-3))
print yerr#.flatten(1)
p1 = fit_and_plot(I_in,v,"Current[A]", "Voltage[V]","V-I plot for finding Z input",zeroed=True,error_bar=yerr)
# Out:
# [  3.59781818e-07   1.12470213e-06   7.58573171e-07   2.84680000e-07
#    3.02254545e-07]
# [  8.23600000e-05   7.97200000e-05   7.81600000e-05   7.01800000e-05]
# [  6.59719504e+03   4.17905999e-01]
#
# 6597 x + 0.4179
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-256-2bc8fa5c8404> in <module>()
#       7 # yerr = np.append(compute_uncertainty(v_in[:-1],0.001),compute_uncertainty(v_in[-1],0.1e-3))
#       8 print yerr#.flatten(1)
# ----> 9 p1 = fit_and_plot(I_in,v,"Current[A]", "Voltage[V]","V-I plot for finding Z input",zeroed=True,error_bar=yerr)
#
# <ipython-input-223-86429d45ec50> in fit_and_plot(x, y, xlabel, ylabel, title, zeroed, annotate_fit, right_words, error_bar)
#      29 #     ax1.text(0.03,0.8,"y= %.5f x %.5f"%(p[0],p[1]), fontsize=13,transform=ax.transAxes)
#      30     if error_bar!="":
# ---> 31         ax1.errorbar(x, y, yerr=error_bar, fmt='o')
#      32     plt.tick_params(axis='both', which='major', labelsize=12)
#      33     plt.tick_params(axis='both', which='minor', labelsize=12)
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/axes.pyc in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    5756                 # using list comps rather than arrays to preserve units
#    5757                 lower = [thisy - thiserr for (thisy, thiserr)
# -> 5758                          in cbook.safezip(y, yerr)]
#    5759                 upper = [thisy + thiserr for (thisy, thiserr)
#    5760                          in cbook.safezip(y, yerr)]
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/cbook.pyc in safezip(*args)
#    1437     for i, arg in enumerate(args[1:]):
#    1438         if len(arg) != Nx:
# -> 1439             raise ValueError(_safezip_msg % (Nx, i + 1, len(arg)))
#    1440     return zip(*args)
#    1441
#
# ValueError: In safezip, len(args[0])=5 but len(args[1])=4

# %% [markdown]
# # 1.2.6

# %%
f = np.array([20,40,100,200,400,1000,2000,10000,20000]) #[Hz]
V_out = np.array([32e-3,488e-3,560e-3,1.2,2.8,5.60,7.6,9.68,9.76]) #[V]
V_in =  np.array([1.02,1.0,1.0,1.0,0.980,0.980,0.980,0.992,0.992]) #[V]
V_ratio  = V_in/V_out

# %%
plt.loglog(V_ratio,f,'o')

# %%
# plt.loglog(V_ratio,f,'o')
fit_and_plot(log(V_ratio),log(f))
# Out:
# [-1.12462331  5.641274  ]
#
# -1.125 x + 5.641
# poly1d([-1.12462331,  5.641274  ])

# %%
deg = [0,22.5,45,77.5,90] #[deg]
phase_difference =  [3.5e6,4e3,1.6e3,450,135] #[deg]

# %%
# arcsin((1./1.07))/180*pi

# %%
def compute_uncertainty(value,basic_range):
    return 0.012/100.*value+0.004/100.*basic_range

# %%
compute_uncertainty(496,1) #[mV]
# Out:
# 0.05956

# %%
compute_uncertainty(490,1) #[mV]
# Out:
# 0.058839999999999996

# %%
compute_uncertainty(510,1) #[mV]
# Out:
# 0.06124
