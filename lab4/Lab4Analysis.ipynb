# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 4.3

# %%
V = np.array([-3.22,-2.87,-2.27,-1.83,-1.26,-704e-3,0])
I = np.array([4e-3, 6e-2, 2.806, 6.9883, 13.259,19.712, 28.378])
plt.plot(V, I)
plt.plot(V, I, 'o')
plt.ylabel("Current")
plt.xlabel("Gate source Voltage")

# %% [markdown]
# # 4.4 Curve Trace for 2N4392

# %%
data= np.loadtxt("JFETTrns.dat")#,delimiter=" ")
v_diode = data[::,0]
i_diode = data[::,1]
plt.semilogy(v_diode,i_diode,'-',label= "Characteristic Curve from Curve Tracer")
plt.title("Characteristic curve of diode",fontsize=12)
plt.ylabel("Current[A]",fontsize=12)
plt.xlabel("Voltage[V]",fontsize=12)
#   VGS  (V)  Current  (A)

# %% [markdown]
# # 4.6

# %% [markdown]
# ### We do indeed find that past the 10V , the current remains  fairly constant, the circuit behaves like a current source

# %%
voltage = np.array([0,1.2,2.3,2.5,3.9,4.8,7,8.6,10,12,14,17,20,22.1,23.5,26,28,30.5,32.1,33.5,34.1])
current = np.array([0.0188,0.0724,1.4117,1.8193,2.5170,2.6005,2.6174,2.6915,2.7104,2.7282,2.7422,2.7619,2.7776,2.7882,2.7935,2.8091,2.8175,2.8220,2.8289,2.8342,2.8364])*10**(-3)
plt.plot(voltage, current)
plt.plot(voltage, current,'o')
start = np.where(voltage>5)[0][0]
end = np.where(voltage>5)[0][-1]
slope = (voltage[start]-voltage[end])/(current[start]-current[end])
slope
# Out:
# 123744.29223744317

# %% [markdown]
# ### 4.10 : Using the flatter region we can compute the $\Delta V$/$\Delta I$ as 123744$\Omega$

# %% [markdown]
# # 4.8

# %%
voltage = np.array([3.9,4.7,6.03,7.7,9.3,10.4,12,13.5,14.7,15.6,16.7,18,19.1,20.5,21])
current = np.array([2.1621,2.2546,2.3819,2.5533,2.6828,2.7018,2.7108,2.79032,2.7994,2.8642,2.9234,2.8823,2.8503,2.8028,2.7388])*10**(-3)
plt.plot(voltage,current,'o')
start = np.where(voltage>8)[0][0]
end = np.where(voltage>8)[0][-1]
slope = (voltage[start]-voltage[end])/(current[start]-current[end])
slope
# Out:
# 208928.57142857119

# %% [markdown]
# ### 4.10: Using the flatter region we can compute the $\Delta V$/$\Delta I$ as 208928$\Omega$
