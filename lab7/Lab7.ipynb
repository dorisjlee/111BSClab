# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 7.1

# %%
# v = np.array([10.3e-3,45.6e-3,101e-3,258e-3,477e-3,771e-3,1.01,1.25,2.56,5.08,8.64])
# i = np.array([0.0002,0.001,0.002,0.005,0.0100,0.015,0.020,0.025,0.05,0.1001,0.1709])*10**(-3)
# plt.plot(i,v,'o')
# plt.plot(i,v,'-')

# %%
def fit_and_plot(x,y,xlabel="",ylabel="",title="",zeroed=False,annotate_fit= True,right_words = False,error_bar="",sci_lim = False,annotate="",right_annotate=False):
#     x=1./x**2
#     y=1./y
#     fig = plt.figure()
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.plot(x,y,'o')
    z = np.polyfit(x,y, 1) 
    print z
    p = np.poly1d(z)
    print p
    if zeroed : 
        a = np.linspace(0,max(x))
    else:
        a = np.linspace(min(x),max(x))
    ax1.plot(a, p(np.linspace(min(x),max(x))),color="red")
    if annotate_fit: 
        slope = z[0]
        intercept = z[1]
        if right_words:    
            ax1.text(0.38,0.85,"y= %.5f x + %.5f"%(slope,intercept), fontsize=13,transform=ax1.transAxes)
        else:
            ax1.text(0.03,0.85,"y= %.5f x + %.5f"%(slope,intercept), fontsize=13,transform=ax1.transAxes)
    if title !="":
        plt.title(title,fontsize=13 )    
        plt.xlabel(xlabel,fontsize=12)
        plt.ylabel(ylabel,fontsize=12)
#     ax1 = fig.add_subplot(111)
#     ax1.text(0.03,0.8,"y= %.5f x %.5f"%(p[0],p[1]), fontsize=13,transform=ax.transAxes)
    if annotate!="":
        if right_annotate: 
            ax1.text(0.48,0.85,annotate, fontsize=13,transform=ax1.transAxes)
    if error_bar!="":
        ax1.errorbar(x, y, yerr=error_bar, fmt='o')
    if sci_lim:
        plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
    plt.tick_params(axis='both', which='major', labelsize=12)
    plt.tick_params(axis='both', which='minor', labelsize=12)
    return p

# %%
fit_and_plot(-i,v,title="VI graph for 7.1",xlabel="Current[A]",ylabel="Voltage[V]",sci_lim=True,right_words=True)
# Out:
# [ -5.06376974e+04  -1.06079878e-03]
#
# -5.064e+04 x - 0.001061
# poly1d([ -5.06376974e+04,  -1.06079878e-03])

# %% [markdown]
# #### Percent Error

# %%
print (5.06376974e04-47e3)/47e3*100,"%"
# Out:
# 7.73978170213 %

# %%
def compute_uncertainty(value,basic_range,mV=False):
    result = 0.012/100.*value+0.004/100.*basic_range
    if (mV):
        return str(result*1e3)+"mV" 
    return result

# %%
# for ii in i:
#     print compute_uncertainty(ii,10e-3,True)

# %%
# for j in v:
#     print compute_uncertainty(j,200e-3,True)

# %% [markdown]
# # 7.4 Chebyshev Filters

# %% [markdown]
# Transfer function $H=V_{out}/V_{in}$

# %% [markdown]
# ##### For the 2 pole Chebyshev low pass filter

# %%
f = np.array([1,10,100,200,300,400,500,600,1e3,10e3,110,120,130,140,150,160,170,180,190])#,100e3,1e6
v_out = np.array([200e-3,816e-3,1.10,640e-3,228e-3,152e-3,96e-3,96e-3,56e-3,32e-3,11.1,1.07,1.04,1.00,952e-3,888e-3,832e-3,768e-3,704e-3])#,24e-3,16.0e-3
v_in = np.array([200e-3,816e-3,1.02e-3,984e-3,960e-3,960e-3,960e-3,960e-3,960e-3,912e-3,1.02,1.02,1.02,1.01,1.01,1.00,992e-3,992e-3,984e-3])#,288e-3,104e-3

plt.figure()
plt.title("Linear plot for transfer function")
plt.xlim(0,10000)
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}/V_{in}$",fontsize=14)
plt.plot(f,v_in/v_out,'o')
# plt.plot(sort(f),sort(v_in/v_out),'r-')

plt.figure()
f = np.array([1,10,100,200,300,400,500,600,1e3,10e3,110,120,130,140,150,160,170,180,190,100e3,1e6])
v_out = np.array([200e-3,816e-3,1.10,640e-3,228e-3,152e-3,96e-3,96e-3,56e-3,32e-3,11.1,1.07,1.04,1.00,952e-3,888e-3,832e-3,768e-3,704e-3,24e-3,16.0e-3])
v_in = np.array([200e-3,816e-3,1.02e-3,984e-3,960e-3,960e-3,960e-3,960e-3,960e-3,912e-3,1.02,1.02,1.02,1.01,1.01,1.00,992e-3,992e-3,984e-3,288e-3,104e-3])
plt.title("Linear-Log plot for transfer function")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}/V_{in}$",fontsize=14)
plt.semilogx(f,v_in/v_out,'o')

plt.figure()
plt.title("Log-Log plot for transfer function")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}/V_{in}$",fontsize=14)
plt.loglog(f,v_in/v_out,'o')

# %% [markdown]
# ##### For the one pole RC filter

# %%
f = np.array([110,120,130,140,150,160,170,180,190,200,210,220,230,240,250,260,270,280,290])
v_out = np.array([960,940,900,880,860,840,820,800,720,760,740,700,680,660,660,660,640,620,620])*10**(-3)
v_in = np.array([1.08,1.08,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3,920e-3])
plt.figure()
plt.title("Linear plot for transfer function")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}/V_{in}$",fontsize=14)
plt.plot(f,v_in/v_out,'o')
plt.plot(sort(f),sort(v_in/v_out),'r-')

plt.figure()
plt.title("Linear-Log plot for transfer function")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}/V_{in}$",fontsize=14)
plt.semilogx(f,v_in/v_out,'o')

plt.figure()
plt.title("Log-Log plot for transfer function")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}/V_{in}$",fontsize=14)
plt.loglog(f,v_in/v_out,'o')

# %% [markdown]
# ##### For the two pole RC filter

# %%
f = np.array([1,10,100,1e3,10e3,100e3,1e6,110,120,130,140,150,160,170,180,190,200,400,600,800])
v_out = np.array([240,736,832,140,124,84,124,784,752,712,664,632,608,576,544,516,468,240,135,152])*10**(-3)
v_in = np.array([196,800,968,936,904,360,152,960,940,940,940,940,940,940,940,940,940,940,940,940])*10**(-3)
plt.figure()
plt.xlim(0,101000)
plt.title("Linear plot for transfer function")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}/V_{in}$",fontsize=14)
plt.plot(f,v_in/v_out,'o')
# plt.plot(sort(f),sort(v_in/v_out),'r-')

f = np.array([1,10,100,1e3,10e3,100e3,1e6,110,120,130,140,150,160,170,180,190,200,400,600,800])
v_out = np.array([240,736,832,140,124,84,124,784,752,712,664,632,608,576,544,516,468,240,135,152])*10**(-3)
v_in = np.array([196,800,968,936,904,360,152,960,940,940,940,940,940,940,940,940,940,940,940,940])*10**(-3)
plt.figure()
plt.title("Linear-Log plot for transfer function")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}/V_{in}$",fontsize=14)
plt.semilogx(f,v_in/v_out,'o')

plt.figure()
plt.title("Log-Log plot for transfer function")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}/V_{in}$",fontsize=14)
plt.loglog(f,v_in/v_out,'o')

# %% [markdown]
# ##### Theoretical Curves for RC Filters

# %%
plt.figure()
plt.title("Theoretical transfer function for RC filter [Linear]")
x = np.linspace(0,1e5,1000)
R=1e3
C=1.0e-6
w_0 = 1./(R*C)
# y= (x/w_0)/np.sqrt(1.+(x/w_0)**2)
# plt.xlim(0,500)
y= np.absolute(1./(1.+((0+1j)*x*R*C)))
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}$",fontsize=14)
plt.plot(x,y,'o')
plt.plot(x,y,'r-')

plt.figure()
plt.title("Theoretical transfer function for RC filter [Log-Linear]")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}$",fontsize=14)
plt.semilogx(x,y,'o')
plt.semilogx(x,y,'r-')

plt.figure()
plt.title("Theoretical transfer function for RC filter [Log-Log]")
plt.xlabel("Frequency [Hz]",fontsize=12 )
plt.ylabel("$V_{out}$",fontsize=14)
plt.loglog(x,y,'o')
plt.loglog(x,y,'r-')

# %% [markdown]
# # 7.6 Logarithm

# %%
v_in = np.array([-8.5,-6.8,-3.64,-684e-3,-3.88e-3,-340e-3])#Yellow
v_out = np.array([799e-3,777e-3,734e-3,620e-3,549e-3,603e-3])#Green
plt.plot(abs(v_in),v_out,'o')
plt.title("Logarithm Circuit")
plt.xlabel("$|V_{in}|$",fontsize=14)
plt.ylabel("$V_{out}$",fontsize=14)

# %% [markdown]
# ##### As seen from the logarithm curve, the general form of the curve that we obtained correpsonds to the functional form. However, there are probably constant factors infront of the log and in the arugment that results in the difference between the two graphs

# %% [markdown]
# # 7.8 Exponentiator

# %%
v_in = np.array([-1.08,-1.28,-1.51,-1.69,-2.24,-2.89,-3.87,-4.67,-94e-3,-562e-3,-610e-3,-580e-3,-900e-3,-603e-3,-588e-3,-598e-3,-601e-3,-201e-3,-32e-3,-422e-3,-478e-3])
v_out = np.array([10.6,10.6,10.5,10.5,10.5,10.4,10.4,10.3,14.9e-3,1.21,8.05,1.57,10.6,5.62,2.46,3.39,6.12,8.03e-3,7.82e-3,202e-3,282e-3])
fig = plt.figure()
ax0 = fig.add_subplot(211)
plt.title("Experimental Data")
plt.xlabel("$|V_{in}|$",fontsize=14)
plt.ylabel("$V_{out}$",fontsize=14)
plt.plot(abs(v_in),v_out,'o')
ax0 = fig.add_subplot(212)
plt.plot(np.linspace(0,70),exp(np.linspace(0,70)),'-')
# plt.xlim(0,.65)
plt.title("General Shape of an Exponential")
# plt.xlabel("$|V_{in}|$",fontsize=14)
plt.xlabel("X")
plt.ylabel("Y")
# plt.ylabel("$V_{out}$",fontsize=14)
plt.tight_layout()
plt.figure()
plt.plot(abs(v_in),v_out,'o')
plt.xlim(0,.65)
plt.title("Experimental Data in region 0 to 0.6V")
plt.xlabel("$|V_{in}|$",fontsize=14)
plt.ylabel("$V_{out}$",fontsize=14)
plt.tight_layout()

# %% [markdown]
# ##### Only exponential behaviour near the $V_{in}$ = 0~0.6V region

# %% [markdown]
# # 7.9 Squaring Module

# %% [markdown]
# The general trend of the data follows a squared behaviour. The reason why$ \sqrt{1} \neq 1$ on our graph is because the diodes on the first and third subcircuit of the squaring module is not matched. Since the circuit effectively exponentiates and logs the signal, therefore if the isat is not matched then it doesn't exactly cancel so the $\sqrt{}$ magnitudes is a bit off.

# %%
v_in = np.array([-13.3e-3,-6.08,-4.55,-2.6,-1.42,-751e-3,-387e-3,-209e-3,-108e-3])
v_out = np.array([334e-3,7.55,5.33,4.48,3.77,3.06,2.37,1.67,850e-3])
plt.plot(v_out,abs(v_in),'o')
# plt.xlim(-2.5,0.6)
plt.title("Behaviour of Squaring module")
plt.xlabel("$|V_{in}|$",fontsize=14)
plt.ylabel("$V_{out}$",fontsize=14)

# %% [markdown]
# # 7.11 Square Root

# %%
v_in = np.array([-8.45,-6.48,-4.91,-3.04,-1.50,-27.8e-3,-751e-3,-516e-3])#Blue (Input)
v_out = np.array([1.98,1.90,1.80,1.72,1.64,835e-3,1.53,1.41])#Red(Output)
plt.plot(abs(v_in),v_out,'o')
plt.title("Behaviour of Squaring Root Module")
plt.xlabel("$|V_{in}|$",fontsize=14)
plt.ylabel("$V_{out}$",fontsize=14)
fig = plt.figure()
ax0 = fig.add_subplot(212)
plt.plot(np.linspace(0,10),sqrt(np.linspace(0,10)),'-')
# plt.xlim(0,.65)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("General Shape of a Square Root")
